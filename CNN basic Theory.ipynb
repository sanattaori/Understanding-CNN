# %% [markdown]
# # Understanding Convolutional Neural Networks

# %% [markdown]
# ## 1. Edge Detection
#
# Given a picture below like that for a computer to figure out what are the objects in this picture, the first thing you might do is maybe detect vertical and horizantal edges in this image.

# %% [markdown]
# <img src="images/edgeb.png">

# %% [markdown]
# ## Vertical Edge Detection

# %% [markdown]
# <img src="images/edge.png">

# %% [markdown]
# <img src="images/vedgeex.png">

# %% [markdown]
# <img src="images/hedge.png">

# %% [markdown]
# ## Sobel Filter
#
# There was a fair amount of debate about what is the best set of numbers to use.
# This is called a Sobel filter.
# */ It turns out that it puts a little bit more weight to the central row *
# <img src="images/ledges.png">

# %% [markdown]
# ## Padding
#
# So maybe, you don't want your image to shrink image every time you detect edges or to set other features on it, so that's one downside.
#
# The second downside is that, if you look the pixel at the corner or the edge, corner little pixel is touched as used only in one of the outputs, because this touches that 3x3 region. Whereas, pixel in the middle, there are a lot of three by three regions that overlap that pixel and so, is as if pixels on the corners or on the edges are use much less in the output.
#
# #### Problems
# * Shrinking output
# * throwing away lot of information

# %% [markdown]
# <img src="images/padding.png">

# %% [markdown]
# ### How Much to Pad?
#
# f - filter dimension
#
# n - matrix dimension
#
# output matrix => n-f+1
#
# * Valid (No Padding)
# * Same (Output size same as input)

# %% [markdown]
# <img src="images/validvssame.png">

# %% [markdown]
# ## Strided Convolutions
#
# Insted of steping over by one step we can step >= 2
#
# Input matrix n*n
#
# padding p
#
# strid s
#
# filter matrix f*f
# ![image.png](attachment:image.png)
